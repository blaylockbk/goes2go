# %% [markdown]
# **Brian Blaylock**
# *December 18, 2020*
#
# # 🌎 ABI Geostationary **field-of-view** in Cartopy
#
# - [GOES-R Series Data Book](https://www.goes-r.gov/downloads/resources/documents/GOES-RSeriesDataBook.pdf)
#     - Full Disk Coverage: Defined as a 17.4 degree diameter circle (pg 48)

# %%
from datetime import datetime
import cartopy.crs as ccrs
import matplotlib.pyplot as plt
from shapely.geometry import Point
import numpy as np

from goes2go.data import goes_latest, goes_nearesttime
from goes2go.tools import field_of_view

from BB_maps.add_to_cartopy import common_features, pc
# Out:
# WARNING! No module named 'dask'
# Without dask, you cannot use dask for multiprocessing.
# /p/home/blaylock/BB_python/Carpenter_Workshop/toolbox/cartopy_tools.py:33: UserWarning: No module named 'geopandas' Without geopandas, you cannot subset some NaturalEarthFeatures, like "Major Highways" from roads.
#   warnings.warn(

# %%
# Testing Phase
gcentral = goes_nearesttime(datetime(2017,10,5), satellite='G16', product='ABI')

# GOES East
g16 = goes_latest(satellite='G16', product='ABI')

# GOES West
g17 = goes_latest(satellite='G17', product='ABI')
# Out:
#  _______________________________
#  | Satellite: noaa-goes16      |
#  |   Product: ABI-L2-MCMIPC    |
#  |    Domain: C                |
# 📦 Finished downloading [1] files to [/p/cwfs/blaylock/data/noaa-goes16/ABI-L2-MCMIPC].
# 📚 Finished reading [1] files into xarray.Dataset.
#  _______________________________
#  | Satellite: noaa-goes16      |
#  |   Product: ABI-L2-MCMIPC    |
#  |    Domain: C                |
# 📦 Finished downloading [1] files to [/p/cwfs/blaylock/data/noaa-goes16/ABI-L2-MCMIPC].
# 📚 Finished reading [1] files into xarray.Dataset.
#  _______________________________
#  | Satellite: noaa-goes17      |
#  |   Product: ABI-L2-MCMIPC    |
#  |    Domain: C                |
# 📦 Finished downloading [1] files to [/p/cwfs/blaylock/data/noaa-goes17/ABI-L2-MCMIPC].
# 📚 Finished reading [1] files into xarray.Dataset.

# %% [markdown]
# ### Get the data's coordinate reference system and field of view with the `goes2go.tools.field_of_view` function
# This returns both the field of view as a shapely polygon and the cartopy coordinate reference system.

# %%
FOV_16, FOV_16dom, crs_16 = field_of_view(g16)
crs_16
# Out:
# <?xml version="1.0" encoding="utf-8" standalone="no"?>
# <!DOCTYPE svg PUBLIC "-//W3C//DTD SVG 1.1//EN"
#   "http://www.w3.org/Graphics/SVG/1.1/DTD/svg11.dtd">
# <svg height="177.48pt" version="1.1" viewBox="0 0 177.48 177.48" width="177.48pt" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink">
#  <metadata>
#   <rdf:RDF xmlns:cc="http://creativecommons.org/ns#" xmlns:dc="http://purl.org/dc/elements/1.1/" xmlns:rdf="http://www.w3.org/1999/02/22-rdf-syntax-ns#">
#    <cc:Work>
#     <dc:type rdf:resource="http://purl.org/dc/dcmitype/StillImage"/>
#     <dc:date>2021-08-18T18:30:55.039395</dc:date>
#     <dc:format>image/svg+xml</dc:format>
#     <dc:creator>
#      <cc:Agent>
#       <dc:title>Matplotlib v3.4.1, https://matplotlib.org/</dc:title>
#      </cc:Agent>
#     </dc:creator>
#    </cc:Work>
#   </rdf:RDF>
#  </metadata>
#  <defs>
#   <style type="text/css">*{stroke-linecap:butt;stroke-linejoin:round;}</style>
#  </defs>
#  <g id="figure_1">
#   <g id="patch_1">
#    <path d="M 0 177.48
# L 177.48 177.48
# L 177.48 0
# L 0 0
# z
# " style="fill:none;"/>
#   </g>
#   <g id="axes_1">
#    <g id="patch_2">
#     <path d="M 170.28 88.74
# L 169.840095 97.230886
# L 168.52455 105.630826
# L 166.345881 113.84967
# L 163.324997 121.798873
# L 159.491247 129.392316
# L 154.882453 136.547159
# L 149.544895 143.184702
# L 143.533216 149.231281
# L 136.910198 154.619159
# L 129.74639 159.287412
# L 122.119538 163.182778
# L 114.113821 166.260452
# L 105.818879 168.484788
# L 97.328641 169.829879
# L 88.74 170.28
# L 80.151359 169.829879
# L 71.661121 168.484788
# L 63.366179 166.260452
# L 55.360462 163.182778
# L 47.73361 159.287412
# L 40.569802 154.619159
# L 33.946784 149.231281
# L 27.935105 143.184702
# L 22.597547 136.547159
# L 17.988753 129.392316
# L 14.155003 121.798873
# L 11.134119 113.84967
# L 8.95545 105.630826
# L 7.639905 97.230886
# L 7.2 88.74
# " style="fill:none;stroke:#000000;"/>
#     <path clip-path="url(#p8056ec68d3)" d="M 46.74075 20.392558
# L 47.220124 20.241282
# L 45.902664 21.16543
# L 45.446788 21.736469
# L 45.273038 21.772527
# L 45.487331 21.456175
# L 45.813664 21.120024
# L 45.935068 20.919224
# L 46.32722 20.58975
# L 46.690825 20.335363

# %%
FOV_16   # See, the FOV is just a shapely polygon

# %%
FOV_16dom  # See the FOV for the ABI product domain (CONUS)

# %%
FOV_17, FOV_17dom, crs_17 = field_of_view(g17)
crs_17
# Out:
# <?xml version="1.0" encoding="utf-8" standalone="no"?>
# <!DOCTYPE svg PUBLIC "-//W3C//DTD SVG 1.1//EN"
#   "http://www.w3.org/Graphics/SVG/1.1/DTD/svg11.dtd">
# <svg height="177.48pt" version="1.1" viewBox="0 0 177.48 177.48" width="177.48pt" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink">
#  <metadata>
#   <rdf:RDF xmlns:cc="http://creativecommons.org/ns#" xmlns:dc="http://purl.org/dc/elements/1.1/" xmlns:rdf="http://www.w3.org/1999/02/22-rdf-syntax-ns#">
#    <cc:Work>
#     <dc:type rdf:resource="http://purl.org/dc/dcmitype/StillImage"/>
#     <dc:date>2021-08-18T18:31:21.284003</dc:date>
#     <dc:format>image/svg+xml</dc:format>
#     <dc:creator>
#      <cc:Agent>
#       <dc:title>Matplotlib v3.4.1, https://matplotlib.org/</dc:title>
#      </cc:Agent>
#     </dc:creator>
#    </cc:Work>
#   </rdf:RDF>
#  </metadata>
#  <defs>
#   <style type="text/css">*{stroke-linecap:butt;stroke-linejoin:round;}</style>
#  </defs>
#  <g id="figure_1">
#   <g id="patch_1">
#    <path d="M 0 177.48
# L 177.48 177.48
# L 177.48 0
# L 0 0
# z
# " style="fill:none;"/>
#   </g>
#   <g id="axes_1">
#    <g id="patch_2">
#     <path d="M 170.28 88.74
# L 169.840095 97.230886
# L 168.52455 105.630826
# L 166.345881 113.84967
# L 163.324997 121.798873
# L 159.491247 129.392316
# L 154.882453 136.547159
# L 149.544895 143.184702
# L 143.533216 149.231281
# L 136.910198 154.619159
# L 129.74639 159.287412
# L 122.119538 163.182778
# L 114.113821 166.260452
# L 105.818879 168.484788
# L 97.328641 169.829879
# L 88.74 170.28
# L 80.151359 169.829879
# L 71.661121 168.484788
# L 63.366179 166.260452
# L 55.360462 163.182778
# L 47.73361 159.287412
# L 40.569802 154.619159
# L 33.946784 149.231281
# L 27.935105 143.184702
# L 22.597547 136.547159
# L 17.988753 129.392316
# L 14.155003 121.798873
# L 11.134119 113.84967
# L 8.95545 105.630826
# L 7.639905 97.230886
# L 7.2 88.74
# L 7.639905 80.249114
# L 8.95545 71.849174
# L 11.134119 63.63033
# L 14.155003 55.681127
# L 17.988753 48.087684
# L 22.597547 40.932841
# L 27.935105 34.295298
# L 33.946784 28.248719
# L 40.569802 22.860841
# L 47.73361 18.192588
# L 55.360462 14.297222
# L 63.366179 11.219548
# L 71.661121 8.995212
# L 80.151359 7.650121
# L 88.74 7.2
# L 97.328641 7.650121
# L 105.818879 8.995212
# L 114.113821 11.219548
# L 122.119538 14.297222
# L 129.74639 18.192588
# L 136.910198 22.860841
# L 143.533216 28.248719
# L 149.544895 34.295298
# L 154.882453 40.932841
# L 159.491247 48.087684
# L 163.324997 55.681127
# L 166.345881 63.63033
# L 168.52455 71.849174
# L 169.840095 80.249114
# L 170.28 88.74
# L 170.28 88.74
# " style="fill:#ffffff;"/>
#    </g>
#    <g id="PathCollection_1">
#     <path clip-path="url(#pe783c5fbf8)" d="M 7.488654 94.311498
# L 7.495698 94.343187
# L 7.606349 95.09671
# L 7.720617 95.836003
# L 7.815026 96.693667
# L 8.12485 97.628498
# L 8.24911 98.405772
# L 8.132155 98.538447
# L 8.283138 99.510241
# L 8.549108 100.487316
# L 8.894202 102.04457
# L 8.994516 102.016336
# L 9.092042 102.656418
# L 9.292167 102.930717
# L 9.275994 103.192665
# L 9.619641 103.842603
# L 9.670822 104.256609
# L 9.541728 104.330754
# L 9.419898 103.946585
# L 9.220627 103.750703
# L 9.006434 103.494749
# L 8.729736 102.547497
# L 8.524871 101.735919
# L 8.273003 100.458158
# L 8.061287 99.789254
# L 8.05891 99.906296
# " style="fill:none;stroke:#000000;"/>
#     <path clip-path="url(#pe783c5fbf8)" d="M 164.482004 61.858134
# L 164.658341 62.014682
# L 164.796171 62.303072
# L 164.84519 62.637811
# L 164.639176 62.580646
# L 164.487386 62.592091
# L 164.274819 61.989992
# L 164.248766 61.795529
# L 164.482004 61.858134
# " style="fill:none;stroke:#000000;"/>
#     <path clip-path="url(#pe783c5fbf8)" d="M
# " style="fill:none;stroke:#000000;"/>
#     <path clip-path="url(#pe783c5fbf8)" d="M 67.776766 13.997082
# L 68.220174 14.009613
# L 68.023945 14.229027
# L 67.520888 14.352139
# L 67.228038 14.275204
# L 67.034355 14.147445
# L 67.776766 13.997082
# " style="fill:none;stroke:#000000;"/>
#     <path clip-path="url(#pe783c5fbf8)" d="M 75.786991 14.906009
# L 76.27446 14.928455
# L 76.489648 15.113199
# L 75.628716 15.446482
# L 74.684835 15.729683
# L 74.387155 15.576358
# L 74.46429 15.276582
# L 75.31422 15.019242
# L 75.786991 14.906009
# " style="fill:none;stroke:#000000;"/>
#     <path clip-path="url(#pe783c5fbf8)" d="M 92.629549 17.336546
# L 93.486971 17.287635
# L 93.351664 18.131198
# L 94.270251 18.762242
# L 93.892683 18.755893
# L 93.269635 18.393999
# L 92.874464 18.038531
# L 92.377286 17.799272
# L 92.167373 17.47092
# L 92.192351 17.237596
# L 92.629549 17.336546
# " style="fill:none;stroke:#000000;"/>
#     <path clip-path="url(#pe783c5fbf8)" d="M 100.272652 20.686743
# L 100.886421 21.103498
# L 101.990526 21.487354
# L 102.566798 21.983295
# L 102.104304 22.091642
# L 100.32976 21.647384
# L 99.93916 21.331279
# L 98.963646 21.009286
# L 98.719517 20.762643
# L 97.663938 20.589095
# L 97.175439 20.12717
# L 97.213016 19.937841
# L 98.279062 20.138755
# L 98.910747 20.278062
# L 99.850729 20.388505
# L

# %%
FOV_central, FOV_centraldom, crs_central = field_of_view(gcentral)
crs_central
# Out:
# <?xml version="1.0" encoding="utf-8" standalone="no"?>
# <!DOCTYPE svg PUBLIC "-//W3C//DTD SVG 1.1//EN"
#   "http://www.w3.org/Graphics/SVG/1.1/DTD/svg11.dtd">
# <svg height="177.48pt" version="1.1" viewBox="0 0 177.48 177.48" width="177.48pt" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink">
#  <metadata>
#   <rdf:RDF xmlns:cc="http://creativecommons.org/ns#" xmlns:dc="http://purl.org/dc/elements/1.1/" xmlns:rdf="http://www.w3.org/1999/02/22-rdf-syntax-ns#">
#    <cc:Work>
#     <dc:type rdf:resource="http://purl.org/dc/dcmitype/StillImage"/>
#     <dc:date>2021-08-18T18:31:42.303192</dc:date>
#     <dc:format>image/svg+xml</dc:format>
#     <dc:creator>
#      <cc:Agent>
#       <dc:title>Matplotlib v3.4.1, https://matplotlib.org/</dc:title>
#      </cc:Agent>
#     </dc:creator>
#    </cc:Work>
#   </rdf:RDF>
#  </metadata>
#  <defs>
#   <style type="text/css">*{stroke-linecap:butt;stroke-linejoin:round;}</style>
#  </defs>
#  <g id="figure_1">
#   <g id="patch_1">
#    <path d="M 0 177.48
# L 177.48 177.48
# L 177.48 0
# L 0 0
# z
# " style="fill:none;"/>
#   </g>
#   <g id="axes_1">
#    <g id="patch_2">
#     <path d="M 170.28 88.74
# L 169.840095 97.230886
# L 168.52455 105.630826
# L 166.345881 113.84967
# L 163.324997 121.798873
# L 159.491247 129.392316
# L 154.882453 136.547159
# L 149.544895 143.184702
# L 143.533216 149.231281
# L 136.910198 154.619159
# L 129.74639 159.287412
# L 122.119538 163.182778
# L 114.113821 166.260452
# L 105.818879 168.484788
# L 97.328641 169.829879
# L 88.74 170.28
# L 80.151359 169.829879
# L 71.661121 168.484788
# L 63.366179 166.260452
# L 55.360462 163.182778
# L 47.73361 159.287412
# L 40.569802 154.619159
# L 33.946784 149.231281
# L 27.935105 143.184702
# L 22.597547 136.547159
# L 17.988753 129.392316
# L 14.155003 121.798873
# L 11.134119 113.84967
# L 8.95545 105.630826
# L 7.639905 97.230886
# L 7.2 88.74
# L 7.639905 80.249114
# L 8.95545 71.849174
# L 11.134119 63.63033
# L 14.155003 55.681127
# L 17.988753 48.087684
# L 22.597547 40.932841
# L 27.935105 34.295298
# L 33.946784 28.248719
# L 40.569802 22.860841
# L 47.73361 18.192588
# L 55.360462 14.297222
# L 63.366179 11.219548
# L 71.661121 8.995212
# L 80.151359 7.650121
# L 88.74 7.2
# L 97.328641 7.650121
# L 105.818879 8.995212
# L 114.113821 11.219548
# L 122.119538 14.297222
# L 129.74639 18.192588
# L 136.910198 22.860841
# L 143.533216 28.248719
# L 149.544895 34.295298
# L 154.882453 40.932841
# L 159.491247 48.087684
# L 163.324997 55.681127
# L 166.345881 63.63033
# L 168.52455 71.849174
# L 169.840095 80.249114
# L 170.28 88.74
# L 170.28 88.74
# " style="fill:#ffffff;"/>
#    </g>
#    <g id="PathCollection_1">
#     <path clip-path="url(
# " style="fill:none;stroke:#000000;"/>
#     <path clip-path="url(#pd949619273)" d="M 93.502436 8.569671
# L 93.797715 8.489811
# L 94.917526 8.640519
# L 95.69819 8.782389
# L 95.92557 8.898796
# L 96.664982 8.875145
# L 97.418246 9.070807
# L 98.71279 9.242505
# L 99.326071 9.386641
# L 100.285473 9.712462
# L 99.635178 9.817048
# L 101.172173 10.117615
# L 102.100711 10.250361
# L 103.40257 10.654833
# L 104.251721 10.74137
# L 104.557847 11.017589
# L 104.349077 11.453065
# L 103.400844 11.217304
# L 101.978249 10.7562
# L 101.33656 10.765214
# L 101.568816 11.000325
# L 102.482611 11.287476
# L 103.525935 11.542556
# L 103.920273 11.680156
# L 104.893843 12.178127
# L 105.112396 12.524122
# L 104.174971 12.337507
# L 102.196459 11.85597
# L 103.526178 12.327217
# L 104.515815 12.674834
# L 104.816194 12.864214
# L 102.853859 12.554949
# L 101.187778 12.190522
# L 100.19466 11.915757
# L 100.294367 11.790514
# L 99.142511 11.50907
# L 98.051296 11.25326
# L 98.167651 11.384118
# L 96.394077 11.394805
# L 95.758697 11.224298
# L 95.959058 10.914734
# L 97.097902 10.944033
# L 98.289066 10.935986
# L 97.953572 10.777912
# L 97.96425 10.582023
# L 98.294888 10.23319
# L 97.960181 10.062446
# L 97.613136 9.930164
# L 96.616926 9.728444
# L 95.441791 9.5765
# L 95.689522 9.504966
# L 94.952522 9.291152
# L 94.49491 9.260197
# L 94.00842 9.147108
# L 93.819538 9.227996
# L 92.934392 9.245357
# L 91.051972 9.147671
# L 89.961094 9.052108
# L 89.146471 9.005493
# L 88.733455 8.906742
# L 89.23134 8.784703
# L 88.555283 8.782991
# L 88.422782 8.530811
# L 88.767074 8.330311
# L 89.194545 8.246589
# L 90.243399 8.20059
# L 89.991331 8.329175
# L 90.386058 8.469184
# L 90.697252 8.298072
# L 91.683264 8.231293
# L 92.615732 8.465049
# L 92.698038 8.616792
# L 93.502436 8.569671
# " style="fill:none;stroke:#000000;"/>
#     <path clip-path="url(#pd949619273)" d="M 49.00636 18.055044
# L 49.124629 18.041561
# L 48.898942 18.219791
# L 48.095283 18.635867
# L 47.367253 19.003289
# L 47.517756 18.864668
# L 48.014154 18.544289
# L 48.677514 18.210161
# L 49.00636 18.055044
# " style="fill:none;stroke:#000000;"/>
#     <path clip-path="url(#pd949619273)" d="M 54.081262 19.14007
# L 54.736818 19.004822
# L 53.554351 19.904641
# L 53.414366 20.476553
# L 53.157733 20.506317
# L 53.170305 20.187747
# L 53.343914 19.853509
# L 53.310963 19.650448
# L 53.593304 19.325995
# L 53.916102 19.078291
# L 54.081262 19.14

# %%
ax = common_features(OCEAN=True, 
                     LAND=True, 
                     crs=ccrs.PlateCarree(central_longitude=-100), 
                     figsize=[10,5], 
                     dark=True)


# Draw boundary of GOES17
ax.add_geometries([FOV_17], crs=crs_17,
                   facecolor='tab:purple', edgecolor='k', alpha=0.3, linewidth=3)
ax.add_geometries([FOV_17], crs=crs_17,
                   facecolor='none', edgecolor='tab:purple', alpha=1, linewidth=3)

# Draw boundary of GOES16
ax.add_geometries([FOV_16], crs=crs_16,
                   facecolor='tab:green', edgecolor='k', alpha=0.3, linewidth=3)
ax.add_geometries([FOV_16], crs=crs_16,
                   facecolor='none', edgecolor='tab:green', alpha=1, linewidth=3)

# Draw boundary of GOES-Central (test phase)
ax.add_geometries([FOV_central], crs=crs_central,
                   facecolor='none', edgecolor='k', alpha=.4, linewidth=3, linestyle='--')


ax.text(g17.geospatial_lat_lon_extent.geospatial_lon_nadir-90,
        g17.geospatial_lat_lon_extent.geospatial_lat_nadir,
        'GOES-West', transform=pc,
       rotation=90, va='center', fontsize=15, color='tab:purple', fontweight='bold')

ax.text(g16.geospatial_lat_lon_extent.geospatial_lon_nadir+80,
        g16.geospatial_lat_lon_extent.geospatial_lat_nadir,
        'GOES-East', transform=pc,
       rotation=-90, va='center', fontsize=15, color='tab:green', fontweight='bold')

plt.title('GOES ABI Field of View', fontsize=20)

plt.savefig('../images/ABI_field-of-view.png')
plt.savefig('../docs/_static/ABI_field-of-view.png')
# Out:
# /p/home/blaylock/anaconda3/envs/goes2go/lib/python3.8/site-packages/cartopy/mpl/feature_artist.py:154: UserWarning: Unable to determine extent. Defaulting to global.
#   warnings.warn('Unable to determine extent. Defaulting to global.')

# %%
ax = common_features(OCEAN=True, 
                     LAND=True, 
                     crs=ccrs.PlateCarree(central_longitude=-100), 
                     figsize=[10,5], 
                     dark=True)


ax.add_geometries(
    [FOV_16], crs=crs_16, facecolor="tab:purple", edgecolor="tab:purple", alpha=0.3, linewidth=3
)
ax.add_geometries(
    [FOV_16dom], crs=crs_16, facecolor="tab:green", edgecolor="tab:green", alpha=0.3, linewidth=3
)

plt.title('GOES-East ABI Field of View and CONUS Domain', fontsize=20)

plt.savefig('../docs/_static/ABI_field-of-view_16dom.png')

# %%
ax = common_features(OCEAN=True, 
                     LAND=True, 
                     crs=ccrs.PlateCarree(central_longitude=-100), 
                     figsize=[10,5], 
                     dark=True)


ax.add_geometries(
    [FOV_17], crs=crs_17, facecolor="tab:purple", edgecolor="tab:purple", alpha=0.3, linewidth=3
)
ax.add_geometries(
    [FOV_17dom], crs=crs_17, facecolor="tab:green", edgecolor="tab:green", alpha=0.3, linewidth=3
)

plt.title('GOES-West ABI Field of View and CONUS Domain', fontsize=20)

plt.savefig('../docs/_static/ABI_field-of-view_17dom.png')

# %%
crs_16.proj4_params
# Out:
# {'a': 6378137.0,
#  'b': 6356752.31414,
#  'rf': 298.2572221,
#  'proj': 'geos',
#  'lon_0': -75.0,
#  'lat_0': 0.0,
#  'h': 35786023.0,
#  'x_0': 0,
#  'y_0': 0,
#  'units': 'm',
#  'sweep': 'x'}

# %%
crs_central.proj4_params
# Out:
# {'a': 6378137.0,
#  'b': 6356752.31414,
#  'rf': 298.2572221,
#  'proj': 'geos',
#  'lon_0': -89.5,
#  'lat_0': 0.0,
#  'h': 35786023.0,
#  'x_0': 0,
#  'y_0': 0,
#  'units': 'm',
#  'sweep': 'x'}

# %%
crs_17.proj4_params
# Out:
# {'a': 6378137.0,
#  'b': 6356752.31414,
#  'rf': 298.2572221,
#  'proj': 'geos',
#  'lon_0': -137.0,
#  'lat_0': 0.0,
#  'h': 35786023.0,
#  'x_0': 0,
#  'y_0': 0,
#  'units': 'm',
#  'sweep': 'x'}

# %% [markdown]
# # Discussion 10: How can I zoom in on the Full Disk Images?

# %%
from goes2go.data import goes_nearesttime
import matplotlib.pyplot as plt
import cartopy.crs as ccrs
import cartopy.feature as cfeature

import metpy

# %%
ds = goes_nearesttime('2021-10-18 18:00',
                      satellite='goes16',
                      domain='F',
                      save_dir='$TMPDIR')
ds
# Out:
#  _______________________________
#  | Satellite: noaa-goes16      |
#  |   Product: ABI-L2-MCMIPF    |
#  |    Domain: F                |
# 📦 Finished downloading [1] files to [$TMPDIR/noaa-goes16/ABI-L2-MCMIPF].
# 📚 Finished reading [1] files into xarray.Dataset.
# <xarray.Dataset>
# Dimensions:                                 (y: 5424, x: 5424, number_of_time_bounds: 2, number_of_image_bounds: 2, band: 1)
# Coordinates: (12/41)
#     t                                       datetime64[ns] ...
#   * y                                       (y) float32 0.1518 ... -0.1518
#   * x                                       (x) float32 -0.1518 ... 0.1518
#     y_image                                 float32 ...
#     x_image                                 float32 ...
#     band_wavelength_C01                     (band) float32 ...
#     ...                                      ...
#     band_id_C15                             (band) int8 ...
#     band_id_C16                             (band) int8 ...
#     dataset_name                            <U74 'OR_ABI-L2-MCMIPF-M6_G16_s20...
#     date_created                            <U22 '2021-10-18T18:10:01.8Z'
#     time_coverage_start                     <U22 '2021-10-18T18:00:20.3Z'
#     time_coverage_end                       <U22 '2021-10-18T18:09:51.7Z'
# Dimensions without coordinates: number_of_time_bounds, number_of_image_bounds, band
# Data variables: (12/125)
#     CMI_C01                                 (y, x) float32 ...
#     DQF_C01                                 (y, x) float32 ...
#     CMI_C02                                 (y, x) float32 ...
#     DQF_C02                                 (y, x) float32 ...
#     CMI_C03                                 (y, x) float32 ...
#     DQF_C03                                 (y, x) float32 ...
#     ...                                      ...
#     std_dev_brightness_temperature_C16      float32 ...
#     percent_uncorrectable_GRB_errors        float32 ...
#     percent_uncorrectable_L0_errors         float32 ...
#     dynamic_algorithm_input_data_container  int32 ...
#     algorithm_product_version_container     int32 ...
#     filename                                <U112 'noaa-goes16/ABI-L2-MCMIPF/...
# Attributes: (12/26)
#     naming_authority:          gov.nesdis.noaa
#     Conventions:               CF-1.7
#     Metadata_Conventions:      Unidata Dataset Discovery v1.0
#     standard_name_vocabulary:  CF Standard Name Table (v35, 20 July 2016)
#     institution:               DOC/NOAA/NESDIS > U.S. Department of Commerce,...
#     project:                   GOES
#     ...                        ...
#     cdm_data_type:             Image
#     processing_level:          National Aeronautics and Space Administration ...
#     timeline_id:               ABI Mode 6
#     production_data_source:    Realtime
#     id:                        b84a6f91-3da6-4ea9-994e-c157237d1d97
#     path:                      ['noaa-goes16/ABI-L2-MCMIPF/2021/291/18/OR_ABI...

# %%
# parse the grid projection data with MetPy
ds = ds.metpy.parse_cf()

# get the cartopy coordinate reference system
crs = ds.metpy_crs.item().to_cartopy()
# Out:
# /p/home/blaylock/anaconda3/envs/goes2go/lib/python3.8/site-packages/metpy/xarray.py:349: UserWarning: More than one time coordinate present for variable "time_bounds".
#   warnings.warn('More than one ' + axis + ' coordinate present for variable'
# /p/home/blaylock/anaconda3/envs/goes2go/lib/python3.8/site-packages/metpy/xarray.py:349: UserWarning: More than one time coordinate present for variable "goes_imager_projection".
#   warnings.warn('More than one ' + axis + ' coordinate present for variable'
# /p/home/blaylock/anaconda3/envs/goes2go/lib/python3.8/site-packages/metpy/xarray.py:349: UserWarning: More than one time coordinate present for variable "y_image_bounds".
#   warnings.warn('More than one ' + axis + ' coordinate present for variable'
# /p/home/blaylock/anaconda3/envs/goes2go/lib/python3.8/site-packages/metpy/xarray.py:349: UserWarning: More than one time coordinate present for variable "x_image_bounds".
#   warnings.warn('More than one ' + axis + ' coordinate present for variable'
# /p/home/blaylock/anaconda3/envs/goes2go/lib/python3.8/site-packages/metpy/xarray.py:349: UserWarning: More than one time coordinate present for variable "nominal_satellite_subpoint_lat".
#   warnings.warn('More than one ' + axis + ' coordinate present for variable'
# /p/home/blaylock/anaconda3/envs/goes2go/lib/python3.8/site-packages/metpy/xarray.py:349: UserWarning: More than one time coordinate present for variable "nominal_satellite_subpoint_lon".
#   warnings.warn('More than one ' + axis + ' coordinate present for variable'
# /p/home/blaylock/anaconda3/envs/goes2go/lib/python3.8/site-packages/metpy/xarray.py:349: UserWarning: More than one time coordinate present for variable "nominal_satellite_height".
#   warnings.warn('More than one ' + axis + ' coordinate present for variable'
# /p/home/blaylock/anaconda3/envs/goes2go/lib/python3.8/site-packages/metpy/xarray.py:349: UserWarning: More than one time coordinate present for variable "geospatial_lat_lon_extent".
#   warnings.warn('More than one ' + axis + ' coordinate present for variable'
# /p/home/blaylock/anaconda3/envs/goes2go/lib/python3.8/site-packages/metpy/xarray.py:349: UserWarning: More than one time coordinate present for variable "dynamic_algorithm_input_data_container".
#   warnings.warn('More than one ' + axis + ' coordinate present for variable'
# /p/home/blaylock/anaconda3/envs/goes2go/lib/python3.8/site-packages/metpy/xarray.py:349: UserWarning: More than one time coordinate present for variable "algorithm_product_version_container".
#   warnings.warn('More than one ' + axis + ' coordinate present for variable'
# /p/home/blaylock/anaconda3/envs/goes2go/lib/python3.8/site-packages/metpy/xarray.py:349: UserWarning: More than one time coordinate present for variable "filename".
#   warnings.warn('More than one ' + axis + ' coordinate present for variable'

# %%
# Plot the data in projection coordinates
fig = plt.figure()
ax = fig.add_subplot(1, 1, 1, projection=crs)
ax.pcolormesh(ds.x, ds.y, ds.CMI_C01)

ax.coastlines(color='dodgerblue')
ax.add_feature(cfeature.BORDERS, color='dodgerblue')

# Zoom (a bit tricky to fine tune because of different projections.)
ax.set_extent([-80, -30, -60, -22], ccrs.PlateCarree())
# Out:
# /p/home/blaylock/anaconda3/envs/goes2go/lib/python3.8/site-packages/cartopy/mpl/style.py:90: UserWarning: facecolor will have no effect as it has been defined as "never".
#   warnings.warn('facecolor will have no effect as it has been '

# %%
# Plot the data in projection coordinates
fig = plt.figure()
ax = fig.add_subplot(1, 1, 1, projection=crs)
ax.coastlines(color='dodgerblue')
ax.add_feature(cfeature.BORDERS, color='dodgerblue')

# Zoom (a bit better to tune in the GOES coordinate reference system)
# [left_limit, right_limit, bottom_limit, top_limit]
ax.set_extent([0, 2_300_000, -5_400_000, -2_000_000], crs)

# %%
ax = plt.subplot(projection=crs)
ax.imshow(ds.rgb.TrueColor(), **ds.rgb.imshow_kwargs)
ax.set_extent([0, 2_300_000, -5_400_000, -2_000_000], crs)

# %%
# Make figure on Cartopy axes
ax = plt.subplot(projection=ds.rgb.crs )
ax.imshow(ds.rgb.TrueColor(), **ds.rgb.imshow_kwargs)
ax.coastlines()

# %%
ds.CMI_C01.plot()

# %%
import metpy

# %%
ds = ds.metpy.parse_cf()
# Out:
# /p/home/blaylock/anaconda3/envs/goes2go/lib/python3.8/site-packages/metpy/xarray.py:349: UserWarning: More than one time coordinate present for variable "time_bounds".
#   warnings.warn('More than one ' + axis + ' coordinate present for variable'
# /p/home/blaylock/anaconda3/envs/goes2go/lib/python3.8/site-packages/metpy/xarray.py:349: UserWarning: More than one time coordinate present for variable "goes_imager_projection".
#   warnings.warn('More than one ' + axis + ' coordinate present for variable'
# /p/home/blaylock/anaconda3/envs/goes2go/lib/python3.8/site-packages/metpy/xarray.py:349: UserWarning: More than one time coordinate present for variable "y_image_bounds".
#   warnings.warn('More than one ' + axis + ' coordinate present for variable'
# /p/home/blaylock/anaconda3/envs/goes2go/lib/python3.8/site-packages/metpy/xarray.py:349: UserWarning: More than one time coordinate present for variable "x_image_bounds".
#   warnings.warn('More than one ' + axis + ' coordinate present for variable'
# /p/home/blaylock/anaconda3/envs/goes2go/lib/python3.8/site-packages/metpy/xarray.py:349: UserWarning: More than one time coordinate present for variable "nominal_satellite_subpoint_lat".
#   warnings.warn('More than one ' + axis + ' coordinate present for variable'
# /p/home/blaylock/anaconda3/envs/goes2go/lib/python3.8/site-packages/metpy/xarray.py:349: UserWarning: More than one time coordinate present for variable "nominal_satellite_subpoint_lon".
#   warnings.warn('More than one ' + axis + ' coordinate present for variable'
# /p/home/blaylock/anaconda3/envs/goes2go/lib/python3.8/site-packages/metpy/xarray.py:349: UserWarning: More than one time coordinate present for variable "nominal_satellite_height".
#   warnings.warn('More than one ' + axis + ' coordinate present for variable'
# /p/home/blaylock/anaconda3/envs/goes2go/lib/python3.8/site-packages/metpy/xarray.py:349: UserWarning: More than one time coordinate present for variable "geospatial_lat_lon_extent".
#   warnings.warn('More than one ' + axis + ' coordinate present for variable'
# /p/home/blaylock/anaconda3/envs/goes2go/lib/python3.8/site-packages/metpy/xarray.py:349: UserWarning: More than one time coordinate present for variable "dynamic_algorithm_input_data_container".
#   warnings.warn('More than one ' + axis + ' coordinate present for variable'
# /p/home/blaylock/anaconda3/envs/goes2go/lib/python3.8/site-packages/metpy/xarray.py:349: UserWarning: More than one time coordinate present for variable "algorithm_product_version_container".
#   warnings.warn('More than one ' + axis + ' coordinate present for variable'
# /p/home/blaylock/anaconda3/envs/goes2go/lib/python3.8/site-packages/metpy/xarray.py:349: UserWarning: More than one time coordinate present for variable "filename".
#   warnings.warn('More than one ' + axis + ' coordinate present for variable'

# %%
ds.metpy_crs.item().to_cartopy()
# Out:
# <?xml version="1.0" encoding="utf-8" standalone="no"?>
# <!DOCTYPE svg PUBLIC "-//W3C//DTD SVG 1.1//EN"
#   "http://www.w3.org/Graphics/SVG/1.1/DTD/svg11.dtd">
# <svg height="177.48pt" version="1.1" viewBox="0 0 177.48 177.48" width="177.48pt" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink">
#  <metadata>
#   <rdf:RDF xmlns:cc="http://creativecommons.org/ns#" xmlns:dc="http://purl.org/dc/elements/1.1/" xmlns:rdf="http://www.w3.org/1999/02/22-rdf-syntax-ns#">
#    <cc:Work>
#     <dc:type rdf:resource="http://purl.org/dc/dcmitype/StillImage"/>
#     <dc:date>2021-10-19T03:00:49.925386</dc:date>
#     <dc:format>image/svg+xml</dc:format>
#     <dc:creator>
#      <cc:Agent>
#       <dc:title>Matplotlib v3.4.1, https://matplotlib.org/</dc:title>
#      </cc:Agent>
#     </dc:creator>
#    </cc:Work>
#   </rdf:RDF>
#  </metadata>
#  <defs>
#   <style type="text/css">*{stroke-linecap:butt;stroke-linejoin:round;}</style>
#  </defs>
#  <g id="figure_1">
#   <g id="patch_1">
#    <path d="M 0 177.48
# L 177.48 177.48
# L 177.48 0
# L 0 0
# z
# " style="fill:none;"/>
#   </g>
#   <g id="axes_1">
#    <g id="patch_2">
#     <path d="M 170.28 88.74
# L 169.840095 97.230886
# L 168.52455 105.630826
# L 166.345881 113.84967
# L 163.324997 121.798873
# L 159.491247 129.392316
# L 154.882453 136.547159
# L 149.544895 143.184702
# L 143.533216 149.231281
# L 136.910198 154.619159
# L 129.74639 159.287412
# L 122.119538 163.182778
# L 114.113821 166.260452
# L 105.818879 168.484788
# L 97.328641 169.829879
# L 88.74 170.28
# L 80.151359 169.829879
# L 71.661121 168.484788
# L 63.366179 166.260452
# L 55.360462 163.182778
# L 47.73361 159.287412
# L 40.569802 154.619159
# L 33.946784 149.231281
# L 27.935105 143.184702
# L 22.597547 136.547159
# L 17.988753 129.392316
# L 14.155003 121.798873
# L 11.134119 113.84967
# L 8.95545 105.630826
# L 7.639905 97.230886
# L 7.2 88.74
# L 7.639905 80.249114
# L 8.95545 71.849174
# L 11.134119 63.63033
# L 14.155003 55.681127
# L 17.988753 48.087684
# L 22.597547 40.932841
# L 27.935105 34.295298
# L 33.946784 28.248719
# L 40.569802 22.860841
# L 47.73361 18.192588
# L 55.360462 14.297222
# L 63.366179 11.219548
# L 71.661121 8.995212
# L 80.151359 7.650121
# L 88.74 7.2
# L 97.328641 7.650121
# L 105.818879 8.995212
# L 114.113821 11.219548
# L 122.119538 14.297222
# L 129.74639 18.192588
# L 136.910198 22.860841
# L 143.533216 28.248719
# L 149.544895 34.295298
# L 154.882453 40.932841
# L 159.491247 48.087684
# L 163.324997 55.681127
# L 166.345881 63.63033
# L 168.52455 71.849174
# L 169.840095 80.249114
# L 170.28 88.74
# L 170.28 88.74
# " style="fill:#ffffff;"/>
#    </g>
#    <g id="PathCollection_1">
#     <path clip-path="url(#p24e9628771)" d="M 134.515507 21.60353
# L 135.360437 22.195486
# L 136.168422 22.854005
# L 136.336175 23.169188
# L 135.749183 22.899007
# L 134.848115 22.11616
# L 133.567419 21.246546
# L 133.070559 20.76568
# L 132.738227 20.479115
# L 132.900114 20.529407
# L 133.860782 21.114098
# L 134.515507 21.60353
# " style="fill:none;stroke:#000000;"/>
#     <path clip-path="url(#p24e9628771)" d="M 102.323928 58.905393
# L 103.118725 59.046598
# L 103.415703 59.352321
# L 103.045884 59.734425
# L 101.882498 59.715622
# L 100.98049 59.762668
# L 100.854863 59.107453
# L 101.061636 58.886214
# L 102.323928 58.905393
# " style="fill:none;stroke:#000000;"/>
#     <path clip-path="url(#p24e9628771)" d="M 84.713304 58.889797
# L 85.765352 59.024471
# L 86.594758 59.390586
# L 86.851556 59.810166
# L 85.745224 59.840381
# L 85.263531 60.098089
# L 84.387266 59.853555
# L 83.501977 59.297621
# L 83.697896 58.947605
# L 84.357834 58.839291
# L 84.713304 58.889797
# " style="fill:none;stroke:#000000;"/>
#     <path clip-path="url(#p24e9628771)" d="M 77.803186 51.922659
# L 79.087921 52.015768
# L 80.264953 52.023666
# L 81.655343 52.511825
# L 82.235786 53.044731
# L 83.656813 52.87278
# L 84.184704 53.215652
# L 85.45551 54.125177
# L 86.399261 54.792231
# L 86.905024 54.771036
# L 87.819537 55.073655
# L 87.705178 55.493796
# L 88.841973 55.554979
# L 90.011944 56.168582
# L 89.830337 56.520509
# L 88.799595 56.711227
# L 87.754804 56.786382
# L 86.686762 56.668273
# L 84.464581 56.819742
# L 85.517568 55.97854
# L 84.896032 55.591232
# L 83.905827 55.494356
# L 83.386558 55.065696
# L 83.049132 54.221518
# L 82.184797 54.283046
# L 80.781356 53.894186
# L 80.340407 53.587678
# L 78.382654 53.373653
# L 77.874689 53.091546
# L 78.460672 52.720995
# L 76.99506 52.658812
# L 75.864725 53.430566
# L 75.242716 53.457335
# L 75.0004 53.818581
# L 74.246597 53.987677
# L 73.618734 53.855112
# L 74.444295 53.391903
# L 74.810446 52.859582
# L 75.509628 52.527526
# L 76.291957 52.235629
# L 77.430846 52.085632
# L 77.803186 51.922659
# " style="fill:none;stroke:#000000;"/>
#     <path clip-path="url(#p24e9628771)" d="M 107.135629 19.816489
# L 106.924862 20.31095
# L 106.676914 21.018355
# L 107.145867 20.758672
# L 107.862302 20.967424
# L 107.686371 21.249902
# L 108.638826 21.523403
# L 108.958821 21.333771
# L 110.027655 21.644105
# L 110.084145 22.271352
# L 110.660312 22.152948
# L 111.035959 22.630331
# L 111.631172 23.206752
# L 111.646055 23.998216
# L 111.221406 24.011414
# L 110.490363 23.804891
# L 110.329428 23.062986
# L 110.002951 22.935026
# L 109.250964 23.678108
# L 108.643867 23.62047
# L 109.142624 23.218329
# L 108.098697 22.956385
# L 107.061973 22.967445
# L 105.112615 22.867829
# L 104.855664 22.594948
# L 105.349988 22.301712
# L 104.823592 22.045398
# L 105.424103 21.547832
# L 105.783402 20.237207
# L 106.118654 19.79501
# L 106.7539 19.551287
# L 107.188176 19.605458
# L 107.135629 19.816489
# " style="fill:none;stroke:#000000;"/>
#     <path clip-path="url(#p24e9628771)" d="M 83.149542 10.956331
# L 83.765585 11.090927
# L 84.440574 11.215728
# L 84.418727 11.430642
# L 84.913394 11.387365
# L 85.338547 11.534228
# L 84.70177 11.690836
# L 83.705293 11.594776
# L 83.425723 11.393286
# L 82.660069 11.654985
# L 81.584868 11.926852
# L 81.514306 11.652437
# L 80.599542 11.723892
# L 81.309883 11.4754
# L 81.614663 11.118539
# L 82.079628 10.721475
# L 82.495046 10.743546
# L 82.496707 10.926305
# L 82.850306 10.852775
# L 83.149542 10.956331
# " style="fill:none;stroke:#000000;"/>
#     <path clip-path="url(#p24e9628771)" d="M 87.056468 8.511341
# L 87.507237 8.417271
# L 88.467591 8.528707
# L 89.096286 8.644109
# L 89.166185 8.755096
# L 90.028132 8.70113
# L 90.576373 8.872656
# L 91.801572 8.997315
# L 92.301471 9.120948
# L 92.965641 9.417415
# L 92.078461 9.551156
# L 93.480544 9.797909
# L 94.40735 9.896624
# L 95.468393 10.25907
# L 96.386751 10.313282
# L 96.436872 10.584408
# L 95.726629 11.039153
# L 94.854281 10.835683
# L 93.685209 10.420337
# L 92.939666 10.45506
# L 92.964097 10.686356
# L 93.723767 10.943879
# L 94.678507 11.163439
# L 95.004368 11.288519
# L 95.677462 11.759017
# L 95.629291 12.10379
# L 94.708674 11.949904
# L 92.877177 11.535532
# L 93.977417 11.964618
# L 94.817405 12.280789
# L 95.007642 12.462287
# L 93.033379 12.222664
# L 91.474044 11.915276
# L 90.607699 11.673423
# L 90.82103 11.542079
# L 89.80318 11.299468
# L 88.846531 11.080575
# L 88.858109 11.209376
# L 86.966305 11.287221
# L 86.444366 11.137712
# L 86.923339 10.815297
# L 88.101692 10.801959
# L 89.388667 10.74823
# L 89.173922 10.599944
# L 89.374919 10.399696
# L 90.094629 10.030529
# L 89.912707 9.868981
# L 89.67997 9.747203
# L 88.825302 9.579651
# L 87.73899 9.469795
# L 88.089884 9.386943
# L 87.56644 9.196508
# L 87.119391 9.182524
# L 86.751283 9.085411
# L 86.448921 9.175595
# L 85.507276 9.227293
# L 83.716033 9.198653
# L 82.754169 9.141763
# L 82.018321 9.124369
# L 81.748754 9.038616
# L 82.397214 8.895153
# L 81.746475 8.918468
# L 81.991303 8.664581
# L 82.651374 8.44536
# L 83.214835 8.342939
# L 84.336141 8.255747
# L 83.850737 8.398243
# L 84.007868 8.52768
# L 84.611872 8.33931
# L 85.743323 8.232309
# L 86.294491 8.437925
# L 86.133185 8.591213
# L 87.056468 8.511341
# " style="fill:none;stroke:#000000;"/>
#     <path clip-path="url(#p24e9628771)" d="M 46.74075 20.392558
# L 47.220124 20.241282
# L 45.902664 21.16543
# L 45.446788 21.736469
# L 45.273038 21.772527
# L 45.487331 21.456175
# L 45.813664 21.120024
# L 45.935068 20.919224
# L 46.32722 20.58975
# L 46.690825 20.335363

# %%
ds = ds.metpy.assign_y_x()
# Out:
# /p/home/blaylock/anaconda3/envs/goes2go/lib/python3.8/site-packages/metpy/xarray.py:349: UserWarning: More than one time coordinate present for variable "CMI_C01".
#   warnings.warn('More than one ' + axis + ' coordinate present for variable'
# /p/home/blaylock/anaconda3/envs/goes2go/lib/python3.8/site-packages/metpy/xarray.py:349: UserWarning: More than one time coordinate present for variable "DQF_C01".
#   warnings.warn('More than one ' + axis + ' coordinate present for variable'
# /p/home/blaylock/anaconda3/envs/goes2go/lib/python3.8/site-packages/metpy/xarray.py:349: UserWarning: More than one time coordinate present for variable "CMI_C02".
#   warnings.warn('More than one ' + axis + ' coordinate present for variable'
# /p/home/blaylock/anaconda3/envs/goes2go/lib/python3.8/site-packages/metpy/xarray.py:349: UserWarning: More than one time coordinate present for variable "DQF_C02".
#   warnings.warn('More than one ' + axis + ' coordinate present for variable'
# /p/home/blaylock/anaconda3/envs/goes2go/lib/python3.8/site-packages/metpy/xarray.py:349: UserWarning: More than one time coordinate present for variable "CMI_C03".
#   warnings.warn('More than one ' + axis + ' coordinate present for variable'
# /p/home/blaylock/anaconda3/envs/goes2go/lib/python3.8/site-packages/metpy/xarray.py:349: UserWarning: More than one time coordinate present for variable "DQF_C03".
#   warnings.warn('More than one ' + axis + ' coordinate present for variable'
# /p/home/blaylock/anaconda3/envs/goes2go/lib/python3.8/site-packages/metpy/xarray.py:349: UserWarning: More than one time coordinate present for variable "CMI_C04".
#   warnings.warn('More than one ' + axis + ' coordinate present for variable'
# /p/home/blaylock/anaconda3/envs/goes2go/lib/python3.8/site-packages/metpy/xarray.py:349: UserWarning: More than one time coordinate present for variable "DQF_C04".
#   warnings.warn('More than one ' + axis + ' coordinate present for variable'
# /p/home/blaylock/anaconda3/envs/goes2go/lib/python3.8/site-packages/metpy/xarray.py:349: UserWarning: More than one time coordinate present for variable "CMI_C05".
#   warnings.warn('More than one ' + axis + ' coordinate present for variable'
# /p/home/blaylock/anaconda3/envs/goes2go/lib/python3.8/site-packages/metpy/xarray.py:349: UserWarning: More than one time coordinate present for variable "DQF_C05".
#   warnings.warn('More than one ' + axis + ' coordinate present for variable'
# /p/home/blaylock/anaconda3/envs/goes2go/lib/python3.8/site-packages/metpy/xarray.py:349: UserWarning: More than one time coordinate present for variable "CMI_C06".
#   warnings.warn('More than one ' + axis + ' coordinate present for variable'
# /p/home/blaylock/anaconda3/envs/goes2go/lib/python3.8/site-packages/metpy/xarray.py:349: UserWarning: More than one time coordinate present for variable "DQF_C06".
#   warnings.warn('More than one ' + axis + ' coordinate present for variable'
# /p/home/blaylock/anaconda3/envs/goes2go/lib/python3.8/site-packages/metpy/xarray.py:349: UserWarning: More than one time coordinate present for variable "CMI_C07".
#   warnings.warn('More than one ' + axis + ' coordinate present for variable'
# /p/home/blaylock/anaconda3/envs/goes2go/lib/python3.8/site-packages/metpy/xarray.py:349: UserWarning: More than one time coordinate present for variable "DQF_C07".
#   warnings.warn('More than one ' + axis + ' coordinate present for variable'
# /p/home/blaylock/anaconda3/envs/goes2go/lib/python3.8/site-packages/metpy/xarray.py:349: UserWarning: More than one time coordinate present for variable "CMI_C08".
#   warnings.warn('More than one ' + axis + ' coordinate present for variable'
# /p/home/blaylock/anaconda3/envs/goes2go/lib/python3.8/site-packages/metpy/xarray.py:349: UserWarning: More than one time coordinate present for variable "DQF_C08".
#   warnings.warn('More than one ' + axis + ' coordinate present for variable'
# /p/home/blaylock/anaconda3/envs/goes2go/lib/python3.8/site-packages/metpy/xarray.py:349: UserWarning: More than one time coordinate present for variable "CMI_C09".
#   warnings.warn('More than one ' + axis + ' coordinate present for variable'
# /p/home/blaylock/anaconda3/envs/goes2go/lib/python3.8/site-packages/metpy/xarray.py:349: UserWarning: More than one time coordinate present for variable "DQF_C09".
#   warnings.warn('More than one ' + axis + ' coordinate present for variable'
# /p/home/blaylock/anaconda3/envs/goes2go/lib/python3.8/site-packages/metpy/xarray.py:349: UserWarning: More than one time coordinate present for variable "CMI_C10".
#   warnings.warn('More than one ' + axis + ' coordinate present for variable'
# /p/home/blaylock/anaconda3/envs/goes2go/lib/python3.8/site-packages/metpy/xarray.py:349: UserWarning: More than one time coordinate present for variable "DQF_C10".
#   warnings.warn('More than one ' + axis + ' coordinate present for variable'
# /p/home/blaylock/anaconda3/envs/goes2go/lib/python3.8/site-packages/metpy/xarray.py:349: UserWarning: More than one time coordinate present for variable "CMI_C11".
#   warnings.warn('More than one ' + axis + ' coordinate present for variable'
# /p/home/blaylock/anaconda3/envs/goes2go/lib/python3.8/site-packages/metpy/xarray.py:349: UserWarning: More than one time coordinate present for variable "DQF_C11".
#   warnings.warn('More than one ' + axis + ' coordinate present for variable'
# /p/home/blaylock/anaconda3/envs/goes2go/lib/python3.8/site-packages/metpy/xarray.py:349: UserWarning: More than one time coordinate present for variable "CMI_C12".
#   warnings.warn('More than one ' + axis + ' coordinate present for variable'
# /p/home/blaylock/anaconda3/envs/goes2go/lib/python3.8/site-packages/metpy/xarray.py:349: UserWarning: More than one time coordinate present for variable "DQF_C12".
#   warnings.warn('More than one ' + axis + ' coordinate present for variable'
# /p/home/blaylock/anaconda3/envs/goes2go/lib/python3.8/site-packages/metpy/xarray.py:349: UserWarning: More than one time coordinate present for variable "CMI_C13".
#   warnings.warn('More than one ' + axis + ' coordinate present for variable'
# /p/home/blaylock/anaconda3/envs/goes2go/lib/python3.8/site-packages/metpy/xarray.py:349: UserWarning: More than one time coordinate present for variable "DQF_C13".
#   warnings.warn('More than one ' + axis + ' coordinate present for variable'
# /p/home/blaylock/anaconda3/envs/goes2go/lib/python3.8/site-packages/metpy/xarray.py:349: UserWarning: More than one time coordinate present for variable "CMI_C14".
#   warnings.warn('More than one ' + axis + ' coordinate present for variable'
# /p/home/blaylock/anaconda3/envs/goes2go/lib/python3.8/site-packages/metpy/xarray.py:349: UserWarning: More than one time coordinate present for variable "DQF_C14".
#   warnings.warn('More than one ' + axis + ' coordinate present for variable'
# /p/home/blaylock/anaconda3/envs/goes2go/lib/python3.8/site-packages/metpy/xarray.py:349: UserWarning: More than one time coordinate present for variable "CMI_C15".
#   warnings.warn('More than one ' + axis + ' coordinate present for variable'
# /p/home/blaylock/anaconda3/envs/goes2go/lib/python3.8/site-packages/metpy/xarray.py:349: UserWarning: More than one time coordinate present for variable "DQF_C15".
#   warnings.warn('More than one ' + axis + ' coordinate present for variable'
# /p/home/blaylock/anaconda3/envs/goes2go/lib/python3.8/site-packages/metpy/xarray.py:349: UserWarning: More than one time coordinate present for variable "CMI_C16".
#   warnings.warn('More than one ' + axis + ' coordinate present for variable'
# /p/home/blaylock/anaconda3/envs/goes2go/lib/python3.8/site-packages/metpy/xarray.py:349: UserWarning: More than one time coordinate present for variable "DQF_C16".
#   warnings.warn('More than one ' + axis + ' coordinate present for variable'
# /p/home/blaylock/anaconda3/envs/goes2go/lib/python3.8/site-packages/metpy/xarray.py:349: UserWarning: More than one time coordinate present for variable "time_bounds".
#   warnings.warn('More than one ' + axis + ' coordinate present for variable'
# /p/home/blaylock/anaconda3/envs/goes2go/lib/python3.8/site-packages/metpy/xarray.py:349: UserWarning: More than one time coordinate present for variable "goes_imager_projection".
#   warnings.warn('More than one ' + axis + ' coordinate present for variable'
# /p/home/blaylock/anaconda3/envs/goes2go/lib/python3.8/site-packages/metpy/xarray.py:349: UserWarning: More than one time coordinate present for variable "y_image_bounds".
#   warnings.warn('More than one ' + axis + ' coordinate present for variable'
# /p/home/blaylock/anaconda3/envs/goes2go/lib/python3.8/site-packages/metpy/xarray.py:349: UserWarning: More than one time coordinate present for variable "x_image_bounds".
#   warnings.warn('More than one ' + axis + ' coordinate present for variable'
# /p/home/blaylock/anaconda3/envs/goes2go/lib/python3.8/site-packages/metpy/xarray.py:349: UserWarning: More than one time coordinate present for variable "nominal_satellite_subpoint_lat".
#   warnings.warn('More than one ' + axis + ' coordinate present for variable'
# /p/home/blaylock/anaconda3/envs/goes2go/lib/python3.8/site-packages/metpy/xarray.py:349: UserWarning: More than one time coordinate present for variable "nominal_satellite_subpoint_lon".
#   warnings.warn('More than one ' + axis + ' coordinate present for variable'
# /p/home/blaylock/anaconda3/envs/goes2go/lib/python3.8/site-packages/metpy/xarray.py:349: UserWarning: More than one time coordinate present for variable "nominal_satellite_height".
#   warnings.warn('More than one ' + axis + ' coordinate present for variable'
# /p/home/blaylock/anaconda3/envs/goes2go/lib/python3.8/site-packages/metpy/xarray.py:349: UserWarning: More than one time coordinate present for variable "geospatial_lat_lon_extent".
#   warnings.warn('More than one ' + axis + ' coordinate present for variable'
# /p/home/blaylock/anaconda3/envs/goes2go/lib/python3.8/site-packages/metpy/xarray.py:349: UserWarning: More than one time coordinate present for variable "outlier_pixel_count_C01".
#   warnings.warn('More than one ' + axis + ' coordinate present for variable'
# /p/home/blaylock/anaconda3/envs/goes2go/lib/python3.8/site-packages/metpy/xarray.py:349: UserWarning: More than one time coordinate present for variable "min_reflectance_factor_C01".
#   warnings.warn('More than one ' + axis + ' coordinate present for variable'
# /p/home/blaylock/anaconda3/envs/goes2go/lib/python3.8/site-packages/metpy/xarray.py:349: UserWarning: More than one time coordinate present for variable "max_reflectance_factor_C01".
#   warnings.warn('More than one ' + axis + ' coordinate present for variable'
# /p/home/blaylock/anaconda3/envs/goes2go/lib/python3.8/site-packages/metpy/xarray.py:349: UserWarning: More than one time coordinate present for variable "mean_reflectance_factor_C01".
#   warnings.warn('More than one ' + axis + ' coordinate present for variable'
# /p/home/blaylock/anaconda3/envs/goes2go/lib/python3.8/site-packages/metpy/xarray.py:349: UserWarning: More than one time coordinate present for variable "std_dev_reflectance_factor_C01".
#   warnings.warn('More than one ' + axis + ' coordinate present for variable'
# /p/home/blaylock/anaconda3/envs/goes2go/lib/python3.8/site-packages/metpy/xarray.py:349: UserWarning: More than one time coordinate present for variable "outlier_pixel_count_C02".
#   warnings.warn('More than one ' + axis + ' coordinate present for variable'
# /p/home/blaylock/anaconda3/envs/goes2go/lib/python3.8/site-packages/metpy/xarray.py:349: UserWarning: More than one time coordinate present for variable "min_reflectance_factor_C02".
#   warnings.warn('More than one ' + axis + ' coordinate present for variable'
# /p/home/blaylock/anaconda3/envs/goes2go/lib/python3.8/site-packages/metpy/xarray.py:349: UserWarning: More than one time coordinate present for variable "max_reflectance_factor_C02".
#   warnings.warn('More than one ' + axis + ' coordinate present for variable'
# /p/home/blaylock/anaconda3/envs/goes2go/lib/python3.8/site-packages/metpy/xarray.py:349: UserWarning: More than one time coordinate present for variable "mean_reflectance_factor_C02".
#   warnings.warn('More than one ' + axis + ' coordinate present for variable'
# /p/home/blaylock/anaconda3/envs/goes2go/lib/python3.8/site-packages/metpy/xarray.py:349: UserWarning: More than one time coordinate present for variable "std_dev_reflectance_factor_C02".
#   warnings.warn('More than one ' + axis + ' coordinate present for variable'
# /p/home/blaylock/anaconda3/envs/goes2go/lib/python3.8/site-packages/metpy/xarray.py:349: UserWarning: More than one time coordinate present for variable "outlier_pixel_count_C03".
#   warnings.warn('More than one ' + axis + ' coordinate present for variable'
# /p/home/blaylock/anaconda3/envs/goes2go/lib/python3.8/site-packages/metpy/xarray.py:349: UserWarning: More than one time coordinate present for variable "min_reflectance_factor_C03".
#   warnings.warn('More than one ' + axis + ' coordinate present for variable'
# /p/home/blaylock/anaconda3/envs/goes2go/lib/python3.8/site-packages/metpy/xarray.py:349: UserWarning: More than one time coordinate present for variable "max_reflectance_factor_C03".
#   warnings.warn('More than one ' + axis + ' coordinate present for variable'
# /p/home/blaylock/anaconda3/envs/goes2go/lib/python3.8/site-packages/metpy/xarray.py:349: UserWarning: More than one time coordinate present for variable "mean_reflectance_factor_C03".
#   warnings.warn('More than one ' + axis + ' coordinate present for variable'
# /p/home/blaylock/anaconda3/envs/goes2go/lib/python3.8/site-packages/metpy/xarray.py:349: UserWarning: More than one time coordinate present for variable "std_dev_reflectance_factor_C03".
#   warnings.warn('More than one ' + axis + ' coordinate present for variable'
# /p/home/blaylock/anaconda3/envs/goes2go/lib/python3.8/site-packages/metpy/xarray.py:349: UserWarning: More than one time coordinate present for variable "outlier_pixel_count_C04".
#   warnings.warn('More than one ' + axis + ' coordinate present for variable'
# /p/home/blaylock/anaconda3/envs/goes2go/lib/python3.8/site-packages/metpy/xarray.py:349: UserWarning: More than one time coordinate present for variable "min_reflectance_factor_C04".
#   warnings.warn('More than one ' + axis + ' coordinate present for variable'
# /p/home/blaylock/anaconda3/envs/goes2go/lib/python3.8/site-packages/metpy/xarray.py:349: UserWarning: More than one time coordinate present for variable "max_reflectance_factor_C04".
#   warnings.warn('More than one ' + axis + ' coordinate present for variable'
# /p/home/blaylock/anaconda3/envs/goes2go/lib/python3.8/site-packages/metpy/xarray.py:349: UserWarning: More than one time coordinate present for variable "mean_reflectance_factor_C04".
#   warnings.warn('More than one ' + axis + ' coordinate present for variable'
# /p/home/blaylock/anaconda3/envs/goes2go/lib/python3.8/site-packages/metpy/xarray.py:349: UserWarning: More than one time coordinate present for variable "std_dev_reflectance_factor_C04".
#   warnings.warn('More than one ' + axis + ' coordinate present for variable'
# /p/home/blaylock/anaconda3/envs/goes2go/lib/python3.8/site-packages/metpy/xarray.py:349: UserWarning: More than one time coordinate present for variable "outlier_pixel_count_C05".
#   warnings.warn('More than one ' + axis + ' coordinate present for variable'
# /p/home/blaylock/anaconda3/envs/goes2go/lib/python3.8/site-packages/metpy/xarray.py:349: UserWarning: More than one time coordinate present for variable "min_reflectance_factor_C05".
#   warnings.warn('More than one ' + axis + ' coordinate present for variable'
# /p/home/blaylock/anaconda3/envs/goes2go/lib/python3.8/site-packages/metpy/xarray.py:349: UserWarning: More than one time coordinate present for variable "max_reflectance_factor_C05".
#   warnings.warn('More than one ' + axis + ' coordinate present for variable'
# /p/home/blaylock/anaconda3/envs/goes2go/lib/python3.8/site-packages/metpy/xarray.py:349: UserWarning: More than one time coordinate present for variable "mean_reflectance_factor_C05".
#   warnings.warn('More than one ' + axis + ' coordinate present for variable'
# /p/home/blaylock/anaconda3/envs/goes2go/lib/python3.8/site-packages/metpy/xarray.py:349: UserWarning: More than one time coordinate present for variable "std_dev_reflectance_factor_C05".
#   warnings.warn('More than one ' + axis + ' coordinate present for variable'
# /p/home/blaylock/anaconda3/envs/goes2go/lib/python3.8/site-packages/metpy/xarray.py:349: UserWarning: More than one time coordinate present for variable "outlier_pixel_count_C06".
#   warnings.warn('More than one ' + axis + ' coordinate present for variable'
# /p/home/blaylock/anaconda3/envs/goes2go/lib/python3.8/site-packages/metpy/xarray.py:349: UserWarning: More than one time coordinate present for variable "min_reflectance_factor_C06".
#   warnings.warn('More than one ' + axis + ' coordinate present for variable'
# /p/home/blaylock/anaconda3/envs/goes2go/lib/python3.8/site-packages/metpy/xarray.py:349: UserWarning: More than one time coordinate present for variable "max_reflectance_factor_C06".
#   warnings.warn('More than one ' + axis + ' coordinate present for variable'
# /p/home/blaylock/anaconda3/envs/goes2go/lib/python3.8/site-packages/metpy/xarray.py:349: UserWarning: More than one time coordinate present for variable "mean_reflectance_factor_C06".
#   warnings.warn('More than one ' + axis + ' coordinate present for variable'
# /p/home/blaylock/anaconda3/envs/goes2go/lib/python3.8/site-packages/metpy/xarray.py:349: UserWarning: More than one time coordinate present for variable "std_dev_reflectance_factor_C06".
#   warnings.warn('More than one ' + axis + ' coordinate present for variable'
# /p/home/blaylock/anaconda3/envs/goes2go/lib/python3.8/site-packages/metpy/xarray.py:349: UserWarning: More than one time coordinate present for variable "outlier_pixel_count_C07".
#   warnings.warn('More than one ' + axis + ' coordinate present for variable'
# /p/home/blaylock/anaconda3/envs/goes2go/lib/python3.8/site-packages/metpy/xarray.py:349: UserWarning: More than one time coordinate present for variable "min_brightness_temperature_C07".
#   warnings.warn('More than one ' + axis + ' coordinate present for variable'
# /p/home/blaylock/anaconda3/envs/goes2go/lib/python3.8/site-packages/metpy/xarray.py:349: UserWarning: More than one time coordinate present for variable "max_brightness_temperature_C07".
#   warnings.warn('More than one ' + axis + ' coordinate present for variable'
# /p/home/blaylock/anaconda3/envs/goes2go/lib/python3.8/site-packages/metpy/xarray.py:349: UserWarning: More than one time coordinate present for variable "mean_brightness_temperature_C07".
#   warnings.warn('More than one ' + axis + ' coordinate present for variable'
# /p/home/blaylock/anaconda3/envs/goes2go/lib/python3.8/site-packages/metpy/xarray.py:349: UserWarning: More than one time coordinate present for variable "std_dev_brightness_temperature_C07".
#   warnings.warn('More than one ' + axis + ' coordinate present for variable'
# /p/home/blaylock/anaconda3/envs/goes2go/lib/python3.8/site-packages/metpy/xarray.py:349: UserWarning: More than one time coordinate present for variable "outlier_pixel_count_C08".
#   warnings.warn('More than one ' + axis + ' coordinate present for variable'
# /p/home/blaylock/anaconda3/envs/goes2go/lib/python3.8/site-packages/metpy/xarray.py:349: UserWarning: More than one time coordinate present for variable "min_brightness_temperature_C08".
#   warnings.warn('More than one ' + axis + ' coordinate present for variable'
# /p/home/blaylock/anaconda3/envs/goes2go/lib/python3.8/site-packages/metpy/xarray.py:349: UserWarning: More than one time coordinate present for variable "max_brightness_temperature_C08".
#   warnings.warn('More than one ' + axis + ' coordinate present for variable'
# /p/home/blaylock/anaconda3/envs/goes2go/lib/python3.8/site-packages/metpy/xarray.py:349: UserWarning: More than one time coordinate present for variable "mean_brightness_temperature_C08".
#   warnings.warn('More than one ' + axis + ' coordinate present for variable'
# /p/home/blaylock/anaconda3/envs/goes2go/lib/python3.8/site-packages/metpy/xarray.py:349: UserWarning: More than one time coordinate present for variable "std_dev_brightness_temperature_C08".
#   warnings.warn('More than one ' + axis + ' coordinate present for variable'
# /p/home/blaylock/anaconda3/envs/goes2go/lib/python3.8/site-packages/metpy/xarray.py:349: UserWarning: More than one time coordinate present for variable "outlier_pixel_count_C09".
#   warnings.warn('More than one ' + axis + ' coordinate present for variable'
# /p/home/blaylock/anaconda3/envs/goes2go/lib/python3.8/site-packages/metpy/xarray.py:349: UserWarning: More than one time coordinate present for variable "min_brightness_temperature_C09".
#   warnings.warn('More than one ' + axis + ' coordinate present for variable'
# /p/home/blaylock/anaconda3/envs/goes2go/lib/python3.8/site-packages/metpy/xarray.py:349: UserWarning: More than one time coordinate present for variable "max_brightness_temperature_C09".
#   warnings.warn('More than one ' + axis + ' coordinate present for variable'
# /p/home/blaylock/anaconda3/envs/goes2go/lib/python3.8/site-packages/metpy/xarray.py:349: UserWarning: More than one time coordinate present for variable "mean_brightness_temperature_C09".
#   warnings.warn('More than one ' + axis + ' coordinate present for variable'
# /p/home/blaylock/anaconda3/envs/goes2go/lib/python3.8/site-packages/metpy/xarray.py:349: UserWarning: More than one time coordinate present for variable "std_dev_brightness_temperature_C09".
#   warnings.warn('More than one ' + axis + ' coordinate present for variable'
# /p/home/blaylock/anaconda3/envs/goes2go/lib/python3.8/site-packages/metpy/xarray.py:349: UserWarning: More than one time coordinate present for variable "outlier_pixel_count_C10".
#   warnings.warn('More than one ' + axis + ' coordinate present for variable'
# /p/home/blaylock/anaconda3/envs/goes2go/lib/python3.8/site-packages/metpy/xarray.py:349: UserWarning: More than one time coordinate present for variable "min_brightness_temperature_C10".
#   warnings.warn('More than one ' + axis + ' coordinate present for variable'
# /p/home/blaylock/anaconda3/envs/goes2go/lib/python3.8/site-packages/metpy/xarray.py:349: UserWarning: More than one time coordinate present for variable "max_brightness_temperature_C10".
#   warnings.warn('More than one ' + axis + ' coordinate present for variable'
# /p/home/blaylock/anaconda3/envs/goes2go/lib/python3.8/site-packages/metpy/xarray.py:349: UserWarning: More than one time coordinate present for variable "mean_brightness_temperature_C10".
#   warnings.warn('More than one ' + axis + ' coordinate present for variable'
# /p/home/blaylock/anaconda3/envs/goes2go/lib/python3.8/site-packages/metpy/xarray.py:349: UserWarning: More than one time coordinate present for variable "std_dev_brightness_temperature_C10".
#   warnings.warn('More than one ' + axis + ' coordinate present for variable'
# /p/home/blaylock/anaconda3/envs/goes2go/lib/python3.8/site-packages/metpy/xarray.py:349: UserWarning: More than one time coordinate present for variable "outlier_pixel_count_C11".
#   warnings.warn('More than one ' + axis + ' coordinate present for variable'
# /p/home/blaylock/anaconda3/envs/goes2go/lib/python3.8/site-packages/metpy/xarray.py:349: UserWarning: More than one time coordinate present for variable "min_brightness_temperature_C11".
#   warnings.warn('More than one ' + axis + ' coordinate present for variable'
# /p/home/blaylock/anaconda3/envs/goes2go/lib/python3.8/site-packages/metpy/xarray.py:349: UserWarning: More than one time coordinate present for variable "max_brightness_temperature_C11".
#   warnings.warn('More than one ' + axis + ' coordinate present for variable'
# /p/home/blaylock/anaconda3/envs/goes2go/lib/python3.8/site-packages/metpy/xarray.py:349: UserWarning: More than one time coordinate present for variable "mean_brightness_temperature_C11".
#   warnings.warn('More than one ' + axis + ' coordinate present for variable'
# /p/home/blaylock/anaconda3/envs/goes2go/lib/python3.8/site-packages/metpy/xarray.py:349: UserWarning: More than one time coordinate present for variable "std_dev_brightness_temperature_C11".
#   warnings.warn('More than one ' + axis + ' coordinate present for variable'
# /p/home/blaylock/anaconda3/envs/goes2go/lib/python3.8/site-packages/metpy/xarray.py:349: UserWarning: More than one time coordinate present for variable "outlier_pixel_count_C12".
#   warnings.warn('More than one ' + axis + ' coordinate present for variable'
# /p/home/blaylock/anaconda3/envs/goes2go/lib/python3.8/site-packages/metpy/xarray.py:349: UserWarning: More than one time coordinate present for variable "min_brightness_temperature_C12".
#   warnings.warn('More than one ' + axis + ' coordinate present for variable'
# /p/home/blaylock/anaconda3/envs/goes2go/lib/python3.8/site-packages/metpy/xarray.py:349: UserWarning: More than one time coordinate present for variable "max_brightness_temperature_C12".
#   warnings.warn('More than one ' + axis + ' coordinate present for variable'
# /p/home/blaylock/anaconda3/envs/goes2go/lib/python3.8/site-packages/metpy/xarray.py:349: UserWarning: More than one time coordinate present for variable "mean_brightness_temperature_C12".
#   warnings.warn('More than one ' + axis + ' coordinate present for variable'
# /p/home/blaylock/anaconda3/envs/goes2go/lib/python3.8/site-packages/metpy/xarray.py:349: UserWarning: More than one time coordinate present for variable "std_dev_brightness_temperature_C12".
#   warnings.warn('More than one ' + axis + ' coordinate present for variable'
# /p/home/blaylock/anaconda3/envs/goes2go/lib/python3.8/site-packages/metpy/xarray.py:349: UserWarning: More than one time coordinate present for variable "outlier_pixel_count_C13".
#   warnings.warn('More than one ' + axis + ' coordinate present for variable'
# /p/home/blaylock/anaconda3/envs/goes2go/lib/python3.8/site-packages/metpy/xarray.py:349: UserWarning: More than one time coordinate present for variable "min_brightness_temperature_C13".
#   warnings.warn('More than one ' + axis + ' coordinate present for variable'
# /p/home/blaylock/anaconda3/envs/goes2go/lib/python3.8/site-packages/metpy/xarray.py:349: UserWarning: More than one time coordinate present for variable "max_brightness_temperature_C13".
#   warnings.warn('More than one ' + axis + ' coordinate present for variable'
# /p/home/blaylock/anaconda3/envs/goes2go/lib/python3.8/site-packages/metpy/xarray.py:349: UserWarning: More than one time coordinate present for variable "mean_brightness_temperature_C13".
#   warnings.warn('More than one ' + axis + ' coordinate present for variable'
# /p/home/blaylock/anaconda3/envs/goes2go/lib/python3.8/site-packages/metpy/xarray.py:349: UserWarning: More than one time coordinate present for variable "std_dev_brightness_temperature_C13".
#   warnings.warn('More than one ' + axis + ' coordinate present for variable'
# /p/home/blaylock/anaconda3/envs/goes2go/lib/python3.8/site-packages/metpy/xarray.py:349: UserWarning: More than one time coordinate present for variable "outlier_pixel_count_C14".
#   warnings.warn('More than one ' + axis + ' coordinate present for variable'
# /p/home/blaylock/anaconda3/envs/goes2go/lib/python3.8/site-packages/metpy/xarray.py:349: UserWarning: More than one time coordinate present for variable "min_brightness_temperature_C14".
#   warnings.warn('More than one ' + axis + ' coordinate present for variable'
# /p/home/blaylock/anaconda3/envs/goes2go/lib/python3.8/site-packages/metpy/xarray.py:349: UserWarning: More than one time coordinate present for variable "max_brightness_temperature_C14".
#   warnings.warn('More than one ' + axis + ' coordinate present for variable'
# /p/home/blaylock/anaconda3/envs/goes2go/lib/python3.8/site-packages/metpy/xarray.py:349: UserWarning: More than one time coordinate present for variable "mean_brightness_temperature_C14".
#   warnings.warn('More than one ' + axis + ' coordinate present for variable'
# /p/home/blaylock/anaconda3/envs/goes2go/lib/python3.8/site-packages/metpy/xarray.py:349: UserWarning: More than one time coordinate present for variable "std_dev_brightness_temperature_C14".
#   warnings.warn('More than one ' + axis + ' coordinate present for variable'
# /p/home/blaylock/anaconda3/envs/goes2go/lib/python3.8/site-packages/metpy/xarray.py:349: UserWarning: More than one time coordinate present for variable "outlier_pixel_count_C15".
#   warnings.warn('More than one ' + axis + ' coordinate present for variable'
# /p/home/blaylock/anaconda3/envs/goes2go/lib/python3.8/site-packages/metpy/xarray.py:349: UserWarning: More than one time coordinate present for variable "min_brightness_temperature_C15".
#   warnings.warn('More than one ' + axis + ' coordinate present for variable'
# /p/home/blaylock/anaconda3/envs/goes2go/lib/python3.8/site-packages/metpy/xarray.py:349: UserWarning: More than one time coordinate present for variable "max_brightness_temperature_C15".
#   warnings.warn('More than one ' + axis + ' coordinate present for variable'
# /p/home/blaylock/anaconda3/envs/goes2go/lib/python3.8/site-packages/metpy/xarray.py:349: UserWarning: More than one time coordinate present for variable "mean_brightness_temperature_C15".
#   warnings.warn('More than one ' + axis + ' coordinate present for variable'
# /p/home/blaylock/anaconda3/envs/goes2go/lib/python3.8/site-packages/metpy/xarray.py:349: UserWarning: More than one time coordinate present for variable "std_dev_brightness_temperature_C15".
#   warnings.warn('More than one ' + axis + ' coordinate present for variable'
# /p/home/blaylock/anaconda3/envs/goes2go/lib/python3.8/site-packages/metpy/xarray.py:349: UserWarning: More than one time coordinate present for variable "outlier_pixel_count_C16".
#   warnings.warn('More than one ' + axis + ' coordinate present for variable'
# /p/home/blaylock/anaconda3/envs/goes2go/lib/python3.8/site-packages/metpy/xarray.py:349: UserWarning: More than one time coordinate present for variable "min_brightness_temperature_C16".
#   warnings.warn('More than one ' + axis + ' coordinate present for variable'
# /p/home/blaylock/anaconda3/envs/goes2go/lib/python3.8/site-packages/metpy/xarray.py:349: UserWarning: More than one time coordinate present for variable "max_brightness_temperature_C16".
#   warnings.warn('More than one ' + axis + ' coordinate present for variable'
# /p/home/blaylock/anaconda3/envs/goes2go/lib/python3.8/site-packages/metpy/xarray.py:349: UserWarning: More than one time coordinate present for variable "mean_brightness_temperature_C16".
#   warnings.warn('More than one ' + axis + ' coordinate present for variable'
# /p/home/blaylock/anaconda3/envs/goes2go/lib/python3.8/site-packages/metpy/xarray.py:349: UserWarning: More than one time coordinate present for variable "std_dev_brightness_temperature_C16".
#   warnings.warn('More than one ' + axis + ' coordinate present for variable'
# /p/home/blaylock/anaconda3/envs/goes2go/lib/python3.8/site-packages/metpy/xarray.py:349: UserWarning: More than one time coordinate present for variable "percent_uncorrectable_GRB_errors".
#   warnings.warn('More than one ' + axis + ' coordinate present for variable'
# /p/home/blaylock/anaconda3/envs/goes2go/lib/python3.8/site-packages/metpy/xarray.py:349: UserWarning: More than one time coordinate present for variable "percent_uncorrectable_L0_errors".
#   warnings.warn('More than one ' + axis + ' coordinate present for variable'
# /p/home/blaylock/anaconda3/envs/goes2go/lib/python3.8/site-packages/metpy/xarray.py:349: UserWarning: More than one time coordinate present for variable "dynamic_algorithm_input_data_container".
#   warnings.warn('More than one ' + axis + ' coordinate present for variable'
# /p/home/blaylock/anaconda3/envs/goes2go/lib/python3.8/site-packages/metpy/xarray.py:349: UserWarning: More than one time coordinate present for variable "algorithm_product_version_container".
#   warnings.warn('More than one ' + axis + ' coordinate present for variable'
# /p/home/blaylock/anaconda3/envs/goes2go/lib/python3.8/site-packages/metpy/xarray.py:349: UserWarning: More than one time coordinate present for variable "filename".
#   warnings.warn('More than one ' + axis + ' coordinate present for variable'
# /p/home/blaylock/anaconda3/envs/goes2go/lib/python3.8/site-packages/metpy/xarray.py:938: UserWarning: No y and x coordinates assigned since horizontal coordinates were not found
#   warnings.warn('No y and x coordinates assigned since horizontal coordinates '

# %%
ds
# Out:
# <xarray.Dataset>
# Dimensions:                                 (y: 5424, x: 5424, number_of_time_bounds: 2, number_of_image_bounds: 2)
# Coordinates:
#     t                                       datetime64[ns] 2021-10-18T18:05:0...
#   * y                                       (y) float32 5.434e+06 ... -5.434e+06
#   * x                                       (x) float32 -5.434e+06 ... 5.434e+06
#     y_image                                 float32 0.0
#     x_image                                 float64 0.0
#     dataset_name                            <U74 'OR_ABI-L2-MCMIPF-M6_G16_s20...
#     date_created                            <U22 '2021-10-18T18:10:01.8Z'
#     time_coverage_start                     <U22 '2021-10-18T18:00:20.3Z'
#     time_coverage_end                       <U22 '2021-10-18T18:09:51.7Z'
#     metpy_crs                               object Projection: geostationary
# Dimensions without coordinates: number_of_time_bounds, number_of_image_bounds
# Data variables: (12/125)
#     CMI_C01                                 (y, x) float32 ...
#     DQF_C01                                 (y, x) float32 ...
#     CMI_C02                                 (y, x) float32 ...
#     DQF_C02                                 (y, x) float32 ...
#     CMI_C03                                 (y, x) float32 ...
#     DQF_C03                                 (y, x) float32 ...
#     ...                                      ...
#     std_dev_brightness_temperature_C16      float64 15.55
#     percent_uncorrectable_GRB_errors        float64 0.0
#     percent_uncorrectable_L0_errors         float64 0.0
#     dynamic_algorithm_input_data_container  int32 -2147483647
#     algorithm_product_version_container     int32 -2147483647
#     filename                                <U112 'noaa-goes16/ABI-L2-MCMIPF/...
# Attributes: (12/26)
#     naming_authority:          gov.nesdis.noaa
#     Conventions:               CF-1.7
#     Metadata_Conventions:      Unidata Dataset Discovery v1.0
#     standard_name_vocabulary:  CF Standard Name Table (v35, 20 July 2016)
#     institution:               DOC/NOAA/NESDIS > U.S. Department of Commerce,...
#     project:                   GOES
#     ...                        ...
#     cdm_data_type:             Image
#     processing_level:          National Aeronautics and Space Administration ...
#     timeline_id:               ABI Mode 6
#     production_data_source:    Realtime
#     id:                        b84a6f91-3da6-4ea9-994e-c157237d1d97
#     path:                      ['noaa-goes16/ABI-L2-MCMIPF/2021/291/18/OR_ABI...

# %%
ds.CMI_C01.plot()

# %%
from toolbox.cartopy_tools import common_features, pc, ccrs

# %%
ax = common_features(crs=ds.metpy_crs.item().to_cartopy()).ax
ax.pcolormesh(ds.x, ds.y, ds.CMI_C01)

# %%
ax = common_features(crs=ds.metpy_crs.item().to_cartopy()).ax
ax.pcolormesh(zoom_ds.x, zoom_ds.y, zoom_ds.CMI_C01)
# Out:
# <__array_function__ internals>:5: UserWarning: Warning: converting a masked element to nan.
# /p/home/blaylock/anaconda3/envs/goes2go/lib/python3.8/site-packages/matplotlib/colors.py:1159: UserWarning: Warning: converting a masked element to nan.
#   data = np.asarray(value)

# %%
goes_crs = ds.metpy_crs.item().to_cartopy()
goes_crs
# Out:
# <?xml version="1.0" encoding="utf-8" standalone="no"?>
# <!DOCTYPE svg PUBLIC "-//W3C//DTD SVG 1.1//EN"
#   "http://www.w3.org/Graphics/SVG/1.1/DTD/svg11.dtd">
# <svg height="177.48pt" version="1.1" viewBox="0 0 177.48 177.48" width="177.48pt" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink">
#  <metadata>
#   <rdf:RDF xmlns:cc="http://creativecommons.org/ns#" xmlns:dc="http://purl.org/dc/elements/1.1/" xmlns:rdf="http://www.w3.org/1999/02/22-rdf-syntax-ns#">
#    <cc:Work>
#     <dc:type rdf:resource="http://purl.org/dc/dcmitype/StillImage"/>
#     <dc:date>2021-10-19T03:11:28.813928</dc:date>
#     <dc:format>image/svg+xml</dc:format>
#     <dc:creator>
#      <cc:Agent>
#       <dc:title>Matplotlib v3.4.1, https://matplotlib.org/</dc:title>
#      </cc:Agent>
#     </dc:creator>
#    </cc:Work>
#   </rdf:RDF>
#  </metadata>
#  <defs>
#   <style type="text/css">*{stroke-linecap:butt;stroke-linejoin:round;}</style>
#  </defs>
#  <g id="figure_1">
#   <g id="patch_1">
#    <path d="M 0 177.48
# L 177.48 177.48
# L 177.48 0
# L 0 0
# z
# " style="fill:none;"/>
#   </g>
#   <g id="axes_1">
#    <g id="patch_2">
#     <path d="M 170.28 88.74
# L 169.840095 97.230886
# L 168.52455 105.630826
# L 166.345881 113.84967
# L 163.324997 121.798873
# L 159.491247 129.392316
# L 154.882453 136.547159
# L 149.544895 143.184702
# L 143.533216 149.231281
# L 136.910198 154.619159
# L 129.74639 159.287412
# L 122.119538 163.182778
# L 114.113821 166.260452
# L 105.818879 168.484788
# L 97.328641 169.829879
# L 88.74 170.28
# L 80.151359 169.829879
# L 71.661121 168.484788
# L 63.366179 166.260452
# L 55.360462 163.182778
# L 47.73361 159.287412
# L 40.569802 154.619159
# L 33.946784 149.231281
# L 27.935105 143.184702
# L 22.597547 136.547159
# L 17.988753 129.392316
# L 14.155003 121.798873
# L 11.134119 113.84967
# L 8.95545 105.630826
# L 7.639905 97.230886
# L 7.2 88.74
# L 7.639905 80.249114
# L 8.95545 71.849174
# L 11.134119 63.63033
# L 14.155003 55.681127
# L 17.988753 48.087684
# L 22.597547 40.932841
# L 27.935105 34.295298
# L 33.946784 28.248719
# L 40.569802 22.860841
# L 47.73361 18.192588
# L 55.360462 14.297222
# L 63.366179 11.219548
# L 71.661121 8.995212
# L 80.151359 7.650121
# L 88.74 7.2
# L 97.328641 7.650121
# L 105.818879 8.995212
# L 114.113821 11.219548
# L 122.119538 14.297222
# L 129.74639 18.192588
# L 136.910198 22.860841
# L 143.533216 28.248719
# L 149.544895 34.295298
# L 154.882453 40.932841
# L 159.491247 48.087684
# L 163.324997 55.681127
# L 166.345881 63.63033
# L 168.52455 71.849174
# L 169.840095 80.249114
# L 170.28 88.74
# L 170.28 88.74
# " style="fill:#ffffff;"/>
#    </g>
#    <g id="PathCollection_1">
#     <path clip-path="url(#pa4d1f23cf1)" d="M 134.515507 21.60353
# L 135.360437 22.195486
# L 136.168422 22.854005
# L 136.336175 23.169188
# L 135.749183 22.899007
# L 134.848115 22.11616
# L 133.567419 21.246546
# L 133.070559 20.76568
# L 132.738227 20.479115
# L 132.900114 20.529407
# L 133.860782 21.114098
# L 134.515507 21.60353
# " style="fill:none;stroke:#000000;"/>
#     <path clip-path="url(#pa4d1f23cf1)" d="M 102.323928 58.905393
# L 103.118725 59.046598
# L 103.415703 59.352321
# L 103.045884 59.734425
# L 101.882498 59.715622
# L 100.98049 59.762668
# L 100.854863 59.107453
# L 101.061636 58.886214
# L 102.323928 58.905393
# " style="fill:none;stroke:#000000;"/>
#     <path clip-path="url(#pa4d1f23cf1)" d="M 84.713304 58.889797
# L 85.765352 59.024471
# L 86.594758 59.390586
# L 86.851556 59.810166
# L 85.745224 59.840381
# L 85.263531 60.098089
# L 84.387266 59.853555
# L 83.501977 59.297621
# L 83.697896 58.947605
# L 84.357834 58.839291
# L 84.713304 58.889797
# " style="fill:none;stroke:#000000;"/>
#     <path clip-path="url(#pa4d1f23cf1)" d="M 77.803186 51.922659
# L 79.087921 52.015768
# L 80.264953 52.023666
# L 81.655343 52.511825
# L 82.235786 53.044731
# L 83.656813 52.87278
# L 84.184704 53.215652
# L 85.45551 54.125177
# L 86.399261 54.792231
# L 86.905024 54.771036
# L 87.819537 55.073655
# L 87.705178 55.493796
# L 88.841973 55.554979
# L 90.011944 56.168582
# L 89.830337 56.520509
# L 88.799595 56.711227
# L 87.754804 56.786382
# L 86.686762 56.668273
# L 84.464581 56.819742
# L 85.517568 55.97854
# L 84.896032 55.591232
# L 83.905827 55.494356
# L 83.386558 55.065696
# L 83.049132 54.221518
# L 82.184797 54.283046
# L 80.781356 53.894186
# L 80.340407 53.587678
# L 78.382654 53.373653
# L 77.874689 53.091546
# L 78.460672 52.720995
# L 76.99506 52.658812
# L 75.864725 53.430566
# L 75.242716 53.457335
# L 75.0004 53.818581
# L 74.246597 53.987677
# L 73.618734 53.855112
# L 74.444295 53.391903
# L 74.810446 52.859582
# L 75.509628 52.527526
# L 76.291957 52.235629
# L 77.430846 52.085632
# L 77.803186 51.922659
# " style="fill:none;stroke:#000000;"/>
#     <path clip-path="url(#pa4d1f23cf1)" d="M 107.135629 19.816489
# L 106.924862 20.31095
# L 106.676914 21.018355
# L 107.145867 20.758672
# L 107.862302 20.967424
# L 107.686371 21.249902
# L 108.638826 21.523403
# L 108.958821 21.333771
# L 110.027655 21.644105
# L 110.084145 22.271352
# L 110.660312 22.152948
# L 111.035959 22.630331
# L 111.631172 23.206752
# L 111.646055 23.998216
# L 111.221406 24.011414
# L 110.490363 23.804891
# L 110.329428 23.062986
# L 110.002951 22.935026
# L 109.250964 23.678108
# L 108.643867 23.62047
# L 109.142624 23.218329
# L 108.098697 22.956385
# L 107.061973 22.967445
# L 105.112615 22.867829
# L 104.855664 22.594948
# L 105.349988 22.301712
# L 104.823592 22.045398
# L 105.424103 21.547832
# L 105.783402 20.237207
# L 106.118654 19.79501
# L 106.7539 19.551287
# L 107.188176 19.605458
# L 107.135629 19.816489
# " style="fill:none;stroke:#000000;"/>
#     <path clip-path="url(#pa4d1f23cf1)" d="M 83.149542 10.956331
# L 83.765585 11.090927
# L 84.440574 11.215728
# L 84.418727 11.430642
# L 84.913394 11.387365
# L 85.338547 11.534228
# L 84.70177 11.690836
# L 83.705293 11.594776
# L 83.425723 11.393286
# L 82.660069 11.654985
# L 81.584868 11.926852
# L 81.514306 11.652437
# L 80.599542 11.723892
# L 81.309883 11.4754
# L 81.614663 11.118539
# L 82.079628 10.721475
# L 82.495046 10.743546
# L 82.496707 10.926305
# L 82.850306 10.852775
# L 83.149542 10.956331
# " style="fill:none;stroke:#000000;"/>
#     <path clip-path="url(#pa4d1f23cf1)" d="M 87.056468 8.511341
# L 87.507237 8.417271
# L 88.467591 8.528707
# L 89.096286 8.644109
# L 89.166185 8.755096
# L 90.028132 8.70113
# L 90.576373 8.872656
# L 91.801572 8.997315
# L 92.301471 9.120948
# L 92.965641 9.417415
# L 92.078461 9.551156
# L 93.480544 9.797909
# L 94.40735 9.896624
# L 95.468393 10.25907
# L 96.386751 10.313282
# L 96.436872 10.584408
# L 95.726629 11.039153
# L 94.854281 10.835683
# L 93.685209 10.420337
# L 92.939666 10.45506
# L 92.964097 10.686356
# L 93.723767 10.943879
# L 94.678507 11.163439
# L 95.004368 11.288519
# L 95.677462 11.759017
# L 95.629291 12.10379
# L 94.708674 11.949904
# L 92.877177 11.535532
# L 93.977417 11.964618
# L 94.817405 12.280789
# L 95.007642 12.462287
# L 93.033379 12.222664
# L 91.474044 11.915276
# L 90.607699 11.673423
# L 90.82103 11.542079
# L 89.80318 11.299468
# L 88.846531 11.080575
# L 88.858109 11.209376
# L 86.966305 11.287221
# L 86.444366 11.137712
# L 86.923339 10.815297
# L 88.101692 10.801959
# L 89.388667 10.74823
# L 89.173922 10.599944
# L 89.374919 10.399696
# L 90.094629 10.030529
# L 89.912707 9.868981
# L 89.67997 9.747203
# L 88.825302 9.579651
# L 87.73899 9.469795
# L 88.089884 9.386943
# L 87.56644 9.196508
# L 87.119391 9.182524
# L 86.751283 9.085411
# L 86.448921 9.175595
# L 85.507276 9.227293
# L 83.716033 9.198653
# L 82.754169 9.141763
# L 82.018321 9.124369
# L 81.748754 9.038616
# L 82.397214 8.895153
# L 81.746475 8.918468
# L 81.991303 8.664581
# L 82.651374 8.44536
# L 83.214835 8.342939
# L 84.336141 8.255747
# L 83.850737 8.398243
# L 84.007868 8.52768
# L 84.611872 8.33931
# L 85.743323 8.232309
# L 86.294491 8.437925
# L 86.133185 8.591213
# L 87.056468 8.511341
# " style="fill:none;stroke:#000000;"/>
#     <path clip-path="url(#pa4d1f23cf1)" d="M 46.74075 20.392558
# L 47.220124 20.241282
# L 45.902664 21.16543
# L 45.446788 21.736469
# L 45.273038 21.772527
# L 45.487331 21.456175
# L 45.813664 21.120024
# L 45.935068 20.919224
# L 46.32722 20.58975
# L 46.690825 20.335363

# %%
extent = [-80, -40, -60, -20]

center_lon = ds.goes_imager_projection.longitude_of_projection_origin

min_lon, _ = goes_crs.transform_point(extent[0], 0, ccrs.PlateCarree())
max_lon, _ = goes_crs.transform_point(extent[1], 0, ccrs.PlateCarree())
_, min_lat = goes_crs.transform_point(center_lon, extent[2], ccrs.PlateCarree())
_, max_lat = goes_crs.transform_point(center_lon, extent[3], ccrs.PlateCarree())

# %%
zoom_ds = ds.where((ds.x>=min_lon)&(ds.x<=max_lon)).where((ds.y>=min_lat)&(ds.y<=max_lat))

ax = common_features(crs=ds.metpy_crs.item().to_cartopy()).BORDERS().ax
ax.pcolormesh(zoom_ds.x, zoom_ds.y, zoom_ds.CMI_C01)
ax.set_extent(extent, pc)

# %%
extent = [-80, -40, -60, -20]  # [min_lon, max_lon, min_lat, max_lat]
ax = common_features(crs=ds.metpy_crs.item().to_cartopy()).BORDERS().ax
ax.pcolormesh(ds.x, ds.y, ds.CMI_C01)
ax.set_extent(extent, pc)

# %%
ds.goes_imager_projection.longitude_of_projection_origin
# Out:
# -75.0

# %%
ax = common_features(crs=ds.metpy_crs.item().to_cartopy()).BORDERS().ax
ax.scatter(*goes_crs.transform_point(-100, 0, ccrs.PlateCarree()))
ax.set_global()
#ax.pcolormesh(ds.x, ds.y, ds.CMI_C01)
